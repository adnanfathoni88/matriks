# %% [markdown]
# <a href="https://colab.research.google.com/github/adnanfathoni88/numerical_methods/blob/main/Interpolasi_Linear_and_Interpolasi_Lagrange.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Adnan Fathoni <br>
# NIM: 24.21.1591 <br>
# kelas: IF10 <br>
#
# https://colab.research.google.com/drive/1BzdfgH-O08TdTbWnpyuGzinLqXMRsvnc?usp=sharing

# %% [markdown]
# # MODUL

# %%
def interpolasi_linear(x1, y1, x2, y2, x):
    # Memastikan x1 dan x2 tidak sama (untuk menghindari pembagian dengan nol)
    if x2 == x1:
        raise ValueError("x1 dan x2 tidak boleh sama, karena pembagi akan nol.")

    # Langkah 1: Menampilkan input awal
    print(f"\nLangkah 1: Diketahui dua titik:")
    print(f"Titik pertama (x1, y1) = ({x1}, {y1})")
    print(f"Titik kedua (x2, y2) = ({x2}, {y2})")

    # Langkah 2: Menampilkan rumus interpolasi linear
    print("\nLangkah 2: Rumus interpolasi linear adalah:")
    print("y = y1 + ((x − x1) / (x2 − x1)) * (y2 − y1)")

    # Langkah 3: Menghitung nilai interpolasi
    y = y1 + ((x - x1) / (x2 - x1)) * (y2 - y1)

    # Langkah 4: Menampilkan langkah perhitungan
    print(f"\nLangkah 3: Menghitung nilai y untuk x = {x}:")
    print(f"y = {y1} + (({x} - {x1}) / ({x2} - {x1})) * ({y2} - {y1})")
    print(f"y = {y1} + ({x} - {x1}) / ({x2} - {x1}) * ({y2} - {y1})")
    print(f"y = {y}")

    return y

def ambil_input():
    try:
        # Mengambil input untuk titik pertama
        x1 = float(input("Masukkan nilai x1: "))
        y1 = float(input("Masukkan nilai y1: "))

        # Mengambil input untuk titik kedua
        x2 = float(input("Masukkan nilai x2: "))
        y2 = float(input("Masukkan nilai y2: "))

        # Mengambil input untuk nilai x yang ingin dihitung
        x = float(input("Masukkan nilai x yang ingin dihitung: "))

        # Memanggil fungsi interpolasi_linear dengan input yang diambil
        hasil = interpolasi_linear(x1, y1, x2, y2, x)
        print(f"Hasil interpolasi pada x = {x} adalah y = {hasil}")

    except ValueError as e:
        print(f"Terjadi kesalahan: {e}")

# Menjalankan program
ambil_input()
# Out:
# Masukkan nilai x1: 1
# Masukkan nilai y1: 0
# Masukkan nilai x2: 6
# Masukkan nilai y2: 3
# Masukkan nilai x yang ingin dihitung: 2
#
# Langkah 1: Diketahui dua titik:
# Titik pertama (x1, y1) = (1.0, 0.0)
# Titik kedua (x2, y2) = (6.0, 3.0)
#
# Langkah 2: Rumus interpolasi linear adalah:
# y = y1 + ((x − x1) / (x2 − x1)) * (y2 − y1)
#
# Langkah 3: Menghitung nilai y untuk x = 2.0:
# y = 0.0 + ((2.0 - 1.0) / (6.0 - 1.0)) * (3.0 - 0.0)
# y = 0.0 + (2.0 - 1.0) / (6.0 - 1.0) * (3.0 - 0.0)
# y = 0.6000000000000001
# Hasil interpolasi pada x = 2.0 adalah y = 0.6000000000000001

# %%
def lagrange_basis(x_values, i, x):
    """Fungsi untuk menghitung basis polinom Lagrange L_i(x) untuk titik i."""
    n = len(x_values)
    basis = 1
    for j in range(n):
        if j != i:
            basis *= (x - x_values[j]) / (x_values[i] - x_values[j])
    return basis

def interpolasi_lagrange(x_values, y_values, x):
    """Fungsi untuk interpolasi Lagrange dan langkah-langkah perhitungannya."""
    n = len(x_values)
    y = 0
    langkah_perhitungan = []  # Untuk menyimpan langkah-langkah perhitungan

    # Langkah 1: Menampilkan input awal
    print(f"\nLangkah 1: Diketahui titik-titik data:")
    for i in range(n):
        print(f"Titik ke-{i}: ({x_values[i]}, {y_values[i]})")

    # Langkah 2: Menghitung polinom interpolasi Lagrange
    print("\nLangkah 2: Menghitung nilai Lagrange untuk setiap titik i:")
    for i in range(n):
        basis = lagrange_basis(x_values, i, x)
        langkah_perhitungan.append(f"L_{i}({x}) = {basis:.4f}")
        y += y_values[i] * basis

    # Langkah 3: Menampilkan langkah perhitungan
    print("\nLangkah 3: Perhitungan setiap Lagrange dan hasil akhirnya:")
    for langkah in langkah_perhitungan:
        print(langkah)

    # Langkah 4: Menampilkan hasil interpolasi
    print(f"\nLangkah 4: Hitung nilai y untuk x = {x} interpolasi Lagrange:")
    print(f"y = [(y_i * L_i(x)) untuk semua i, di mana y = {y:.4f}")

    return y

def ambil_input():
    """Fungsi untuk mengambil input dan menampilkan perhitungan rinci"""
    try:
        # Jumlah titik
        n = int(input("Masukkan jumlah titik data: "))

        x_values = []
        y_values = []

        # Input titik data
        for i in range(n):
            x = float(input(f"Masukkan nilai x{str(i)}: "))
            y = float(input(f"Masukkan nilai y{str(i)}: "))
            x_values.append(x)
            y_values.append(y)

        # Nilai x yang ingin diperkirakan
        x = float(input("Masukkan nilai x yang ingin diperkirakan: "))

        # Fungsi interpolasi dan menampilkan hasil
        y = interpolasi_lagrange(x_values, y_values, x)
        print(f"\nHasil interpolasi: Nilai y pada x = {x} adalah {y:.4f}")

    except ValueError as e:
        print(f"Terjadi kesalahan: {e}")
        # Input ulang jika terjadi kesalahan
        ambil_input()

# Menjalankan fungsi untuk mengambil input dan menghitung interpolasi
ambil_input()
# Out:
# Masukkan jumlah titik data: 3
# Masukkan nilai x0: 1
# Masukkan nilai y0: 30
# Masukkan nilai x1: 2
# Masukkan nilai y1: 45
# Masukkan nilai x2: 3
# Masukkan nilai y2: 65
# Masukkan nilai x yang ingin diperkirakan: 2.5
#
# Langkah 1: Diketahui titik-titik data:
# Titik ke-0: (1.0, 30.0)
# Titik ke-1: (2.0, 45.0)
# Titik ke-2: (3.0, 65.0)
#
# Langkah 2: Menghitung nilai Lagrange untuk setiap titik i:
#
# Langkah 3: Perhitungan setiap Lagrange dan hasil akhirnya:
# L_0(2.5) = -0.1250
# L_1(2.5) = 0.7500
# L_2(2.5) = 0.3750
#
# Langkah 4: Hitung nilai y untuk x = 2.5 interpolasi Lagrange:
# y = [(y_i * L_i(x)) untuk semua i, di mana y = 54.3750
#
# Hasil interpolasi: Nilai y pada x = 2.5 adalah 54.3750

# %% [markdown]
# # PERCOBAAN

# %% [markdown]
# soal teori 1

# %%
def lagrange_basis(x_values, i, x):
    """Fungsi untuk menghitung basis polinom Lagrange L_i(x) untuk titik i."""
    n = len(x_values)
    basis = 1
    for j in range(n):
        if j != i:
            basis *= (x - x_values[j]) / (x_values[i] - x_values[j])
    return basis

def interpolasi_lagrange(x_values, y_values, x):
    """Fungsi untuk interpolasi Lagrange dan langkah-langkah perhitungannya."""
    n = len(x_values)
    y = 0
    langkah_perhitungan = []  # Untuk menyimpan langkah-langkah perhitungan

    # Langkah 1: Menampilkan input awal
    print(f"\nLangkah 1: Diketahui titik-titik data:")
    for i in range(n):
        print(f"Titik ke-{i}: ({x_values[i]}, {y_values[i]})")

    # Langkah 2: Menghitung polinom interpolasi Lagrange
    print("\nLangkah 2: Menghitung nilai Lagrange untuk setiap titik i:")
    for i in range(n):
        basis = lagrange_basis(x_values, i, x)
        langkah_perhitungan.append(f"L_{i}({x}) = {basis:.4f}")
        y += y_values[i] * basis

    # Langkah 3: Menampilkan langkah perhitungan
    print("\nLangkah 3: Perhitungan setiap Lagrange dan hasil akhirnya:")
    for langkah in langkah_perhitungan:
        print(langkah)

    # Langkah 4: Menampilkan hasil interpolasi
    print(f"\nLangkah 4: Hitung nilai y untuk x = {x} interpolasi Lagrange:")
    print(f"y = [(y_i * L_i(x)) untuk semua i, di mana y = {y:.4f}")

    return y

def ambil_input():
    """Fungsi untuk mengambil input dan menampilkan perhitungan rinci"""
    try:
        # Jumlah titik
        n = int(input("Masukkan jumlah titik data: "))

        x_values = []
        y_values = []

        # Input titik data
        for i in range(n):
            x = float(input(f"Masukkan nilai x{str(i)}: "))
            y = float(input(f"Masukkan nilai y{str(i)}: "))
            x_values.append(x)
            y_values.append(y)

        # Nilai x yang ingin diperkirakan
        x = float(input("Masukkan nilai x yang ingin diperkirakan: "))

        # Fungsi interpolasi dan menampilkan hasil
        y = interpolasi_lagrange(x_values, y_values, x)
        print(f"\nHasil interpolasi: Nilai y pada x = {x} adalah {y:.4f}")

    except ValueError as e:
        print(f"Terjadi kesalahan: {e}")
        # Input ulang jika terjadi kesalahan
        ambil_input()

# Menjalankan fungsi untuk mengambil input dan menghitung interpolasi
ambil_input()
# Out:
# Masukkan jumlah titik data: 10
# Masukkan nilai x0: 1
# Masukkan nilai y0: 30
# Masukkan nilai x1: 2
# Masukkan nilai y1: 45
# Masukkan nilai x2: 3
# Masukkan nilai y2: 65
# Masukkan nilai x3: 4
# Masukkan nilai y3: 75
# Masukkan nilai x4: 5
# Masukkan nilai y4: 100
# Masukkan nilai x5: 6
# Masukkan nilai y5: 120
# Masukkan nilai x6: 7
# Masukkan nilai y6: 155
# Masukkan nilai x7: 8
# Masukkan nilai y7: 180
# Masukkan nilai x8: 9
# Masukkan nilai y8: 200
# Masukkan nilai x9: 10
# Masukkan nilai y9: 215
# Masukkan nilai x yang ingin diperkirakan: 4.5
#
# Langkah 1: Diketahui titik-titik data:
# Titik ke-0: (1.0, 30.0)
# Titik ke-1: (2.0, 45.0)
# Titik ke-2: (3.0, 65.0)
# Titik ke-3: (4.0, 75.0)
# Titik ke-4: (5.0, 100.0)
# Titik ke-5: (6.0, 120.0)
# Titik ke-6: (7.0, 155.0)
# Titik ke-7: (8.0, 180.0)
# Titik ke-8: (9.0, 200.0)
# Titik ke-9: (10.0, 215.0)
#
# Langkah 2: Menghitung nilai Lagrange untuk setiap titik i:
#
# Langkah 3: Perhitungan setiap Lagrange dan hasil akhirnya:
# L_0(4.5) = -0.0008
# L_1(4.5) = 0.0106
# L_2(4.5) = -0.0705
# L_3(4.5) = 0.4935
# L_4(4.5) = 0.7402
# L_5(4.5) = -0.2467
# L_6(4.5) = 0.0987
# L_7(4.5) = -0.0302
# L_8(4.5) = 0.0059
# L_9(4.5) = -0.0005
#
# Langkah 4: Hitung nilai y untuk x = 4.5 interpolasi Lagrange:
# y = [(y_i * L_i(x)) untuk semua i, di mana y = 88.2103
#
# Hasil interpolasi: Nilai y pada x = 4.5 adalah 88.2103

# %% [markdown]
# soal teori 2

# %%
def lagrange_basis(x_values, i, x):
    """Fungsi untuk menghitung basis polinom Lagrange L_i(x) untuk titik i."""
    n = len(x_values)
    basis = 1
    for j in range(n):
        if j != i:
            basis *= (x - x_values[j]) / (x_values[i] - x_values[j])
    return basis

def interpolasi_lagrange(x_values, y_values, x):
    """Fungsi untuk interpolasi Lagrange dan langkah-langkah perhitungannya."""
    n = len(x_values)
    y = 0
    langkah_perhitungan = []  # Untuk menyimpan langkah-langkah perhitungan

    # Langkah 1: Menampilkan input awal
    print(f"\nLangkah 1: Diketahui titik-titik data:")
    for i in range(n):
        print(f"Titik ke-{i}: ({x_values[i]}, {y_values[i]})")

    # Langkah 2: Menghitung polinom interpolasi Lagrange
    print("\nLangkah 2: Menghitung nilai Lagrange untuk setiap titik i:")
    for i in range(n):
        basis = lagrange_basis(x_values, i, x)
        langkah_perhitungan.append(f"L_{i}({x}) = {basis:.4f}")
        y += y_values[i] * basis

    # Langkah 3: Menampilkan langkah perhitungan
    print("\nLangkah 3: Perhitungan setiap Lagrange dan hasil akhirnya:")
    for langkah in langkah_perhitungan:
        print(langkah)

    # Langkah 4: Menampilkan hasil interpolasi
    print(f"\nLangkah 4: Hitung nilai y untuk x = {x} interpolasi Lagrange:")
    print(f"y = [(y_i * L_i(x)) untuk semua i, di mana y = {y:.4f}")

    return y

def ambil_input():
    """Fungsi untuk mengambil input dan menampilkan perhitungan rinci"""
    try:
        # Jumlah titik
        n = int(input("Masukkan jumlah titik data: "))

        x_values = []
        y_values = []

        # Input titik data
        for i in range(n):
            x = float(input(f"Masukkan nilai x{str(i)}: "))
            y = float(input(f"Masukkan nilai y{str(i)}: "))
            x_values.append(x)
            y_values.append(y)

        # Nilai x yang ingin diperkirakan
        x = float(input("Masukkan nilai x yang ingin diperkirakan: "))

        # Fungsi interpolasi dan menampilkan hasil
        y = interpolasi_lagrange(x_values, y_values, x)
        print(f"\nHasil interpolasi: Nilai y pada x = {x} adalah {y:.4f}")

    except ValueError as e:
        print(f"Terjadi kesalahan: {e}")
        # Input ulang jika terjadi kesalahan
        ambil_input()

# Menjalankan fungsi untuk mengambil input dan menghitung interpolasi
ambil_input()
# Out:
# Masukkan jumlah titik data: 6
# Masukkan nilai x0: 1940
# Masukkan nilai y0: 132165
# Masukkan nilai x1: 1950
# Masukkan nilai y1: 151326
# Masukkan nilai x2: 1960
# Masukkan nilai y2: 179323
# Masukkan nilai x3: 1970
# Masukkan nilai y3: 203302
# Masukkan nilai x4: 1980
# Masukkan nilai y4: 226542
# Masukkan nilai x5: 1990
# Masukkan nilai y5: 249633
# Masukkan nilai x yang ingin diperkirakan: 1981
#
# Langkah 1: Diketahui titik-titik data:
# Titik ke-0: (1940.0, 132165.0)
# Titik ke-1: (1950.0, 151326.0)
# Titik ke-2: (1960.0, 179323.0)
# Titik ke-3: (1970.0, 203302.0)
# Titik ke-4: (1980.0, 226542.0)
# Titik ke-5: (1990.0, 249633.0)
#
# Langkah 2: Menghitung nilai Lagrange untuk setiap titik i:
#
# Langkah 3: Perhitungan setiap Lagrange dan hasil akhirnya:
# L_0(1981.0) = 0.0054
# L_1(1981.0) = -0.0355
# L_2(1981.0) = 0.1049
# L_3(1981.0) = -0.2002
# L_4(1981.0) = 1.1010
# L_5(1981.0) = 0.0245
#
# Langkah 4: Hitung nilai y untuk x = 1981.0 interpolasi Lagrange:
# y = [(y_i * L_i(x)) untuk semua i, di mana y = 228972.4517
#
# Hasil interpolasi: Nilai y pada x = 1981.0 adalah 228972.4517
