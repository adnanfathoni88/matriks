# %% [markdown]
# <a href="https://colab.research.google.com/github/adnanfathoni88/numerical_methods/blob/main/secant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Adnan Fathoni <br>
# NIM : 24.21.1591 <br>
# Kelas : IF 10 <br>
#
# link: https://colab.research.google.com/drive/1UUShPRsd_ZWKNxaCjb_n0NQ28E2PJKAQ?usp=sharing

# %% [markdown]
# **METODE SECANT**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fungsi yang ingin dicari akarnya
def f(x):
    return x**2 - 2*x - 2  # Fungsi contoh: f(x)

# Metode Secant
def secant_method(f, x0, x1, tol=1e-6, max_iter=100):
    iterasi = 0
    x_values = [x0, x1]  # Menyimpan nilai x untuk grafik dan iterasi
    print(f"Iterasi 0: x0 = {x0}, f(x0) = {f(x0)}")
    print(f"Iterasi 1: x1 = {x1}, f(x1) = {f(x1)}")

    while iterasi < max_iter:
        # Hitung nilai f(x) di kedua titik
        f_x0 = f(x0)
        f_x1 = f(x1)

        # Formula metode secant
        x2 = x1 - f_x1 * (x1 - x0) / (f_x1 - f_x0)

        # Menambahkan nilai x2 ke daftar untuk grafik
        x_values.append(x2)

        # Menampilkan iterasi
        print(f"Iterasi {iterasi + 2}: x2 = {x2}, f(x2) = {f(x2)}")

        # Jika perubahan antara x1 dan x2 cukup kecil, berhenti
        if abs(x2 - x1) < tol:
            break

        # Update x0 dan x1 untuk iterasi berikutnya
        x0, x1 = x1, x2
        iterasi += 1

    return x2, iterasi, x_values

# Parameter awal
x0 = 3.0  # Titik awal x0
x1 = 4.0  # Titik awal x1

# Menjalankan metode secant
akar, iterasi, x_values = secant_method(f, x0, x1)

# Menampilkan hasil akar dan jumlah iterasi
print(f"\nAkar yang ditemukan: {akar}")
print(f"Jumlah iterasi: {iterasi}")

# Membuat grafik fungsi dan titik iterasi
x = np.linspace(0, 5, 400)
y = f(x)

# Plot grafik fungsi
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="f(x) = x^2 - 2x - 2", color="blue")
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)

# Plot titik-titik iterasi metode secant
for i, xi in enumerate(x_values):
    plt.plot(xi, f(xi), 'ro')  # Titik merah untuk iterasi
    plt.text(xi, f(xi), f' Iter {i}', color='red')

# Menambahkan label dan title
plt.title('Grafik Fungsi dan Iterasi Metode Secant')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Iterasi 0: x0 = 3.0, f(x0) = 1.0
# Iterasi 1: x1 = 4.0, f(x1) = 6.0
# Iterasi 2: x2 = 2.8, f(x2) = 0.23999999999999932
# Iterasi 3: x2 = 2.75, f(x2) = 0.0625
# Iterasi 4: x2 = 2.732394366197183, f(x2) = 0.00119024003173962
# Iterasi 5: x2 = 2.732052578361982, f(x2) = 6.134210389419081e-06
# Iterasi 6: x2 = 2.732050807744481, f(x2) = 6.08309846938937e-10
# Iterasi 7: x2 = 2.732050807568877, f(x2) = 0.0
#
# Akar yang ditemukan: 2.732050807568877
# Jumlah iterasi: 5

# %% [markdown]
# **TUGAS 8**

# %% [markdown]
# # 1

# %% [markdown]
# x0=2, x1=3

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fungsi yang ingin dicari akarnya
def f(x):
    # f(x) = x^3 - 2x^2 + 2x - 5 = 0
    return x**3 - 2*x**2 + 2*x - 5

# Metode Secant
def secant_method(f, x0, x1, tol=0.01, max_iter=100):
    iterasi = 0
    x_values = [x0, x1]  # Menyimpan nilai x untuk grafik dan iterasi
    print(f"Iterasi 0: x0 = {x0}, f(x0) = {f(x0)}")
    print(f"Iterasi 1: x1 = {x1}, f(x1) = {f(x1)}")

    while iterasi < max_iter:
        # Hitung nilai f(x) di kedua titik
        f_x0 = f(x0)
        f_x1 = f(x1)

        # Formula metode secant
        x2 = x1 - f_x1 * (x1 - x0) / (f_x1 - f_x0)

        # Menambahkan nilai x2 ke daftar untuk grafik
        x_values.append(x2)

        # Menampilkan iterasi
        print(f"Iterasi {iterasi + 2}: x2 = {x2}, f(x2) = {f(x2)}")

        # Jika perubahan antara x1 dan x2 cukup kecil, berhenti
        if abs(x2 - x1) < tol:
            break

        # Update x0 dan x1 untuk iterasi berikutnya
        x0, x1 = x1, x2
        iterasi += 1

    return x2, iterasi, x_values

# Parameter awal
x0 = 2.0  # Titik awal x0
x1 = 3.0  # Titik awal x1

# Menjalankan metode secant
akar, iterasi, x_values = secant_method(f, x0, x1)

# Menampilkan hasil akar dan jumlah iterasi
print(f"\nAkar yang ditemukan: {akar}")
print(f"Jumlah iterasi: {iterasi}")

# Membuat grafik fungsi dan titik iterasi
x = np.linspace(0, 5, 400)
y = f(x)

# Plot grafik fungsi
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="f(x) = x^3 - 2x^2 + 2x - 5 = 0", color="blue")
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)

# Plot titik-titik iterasi metode secant
for i, xi in enumerate(x_values):
    plt.plot(xi, f(xi), 'ro')  # Titik merah untuk iterasi
    plt.text(xi, f(xi), f' Iter {i}', color='red')

# Menambahkan label dan title
plt.title('Grafik Fungsi dan Iterasi Metode Secant')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Iterasi 0: x0 = 2.0, f(x0) = -1.0
# Iterasi 1: x1 = 3.0, f(x1) = 10.0
# Iterasi 2: x2 = 2.090909090909091, f(x2) = -0.42073628850488376
# Iterasi 3: x2 = 2.1276135544340304, f(x2) = -0.1670995815782117
# Iterasi 4: x2 = 2.1517949931988984, f(x2) = 0.006434456759063956
# Iterasi 5: x2 = 2.1508983712819805, f(x2) = -9.249451738480019e-05
#
# Akar yang ditemukan: 2.1508983712819805
# Jumlah iterasi: 3

# %% [markdown]
# x0=1, x1=3

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fungsi yang ingin dicari akarnya
def f(x):
    # f(x) = x^3 - 2x^2 + 2x - 5 = 0
    return x**3 - 2*x**2 + 2*x - 5

# Metode Secant
def secant_method(f, x0, x1, tol=0.01, max_iter=100):
    iterasi = 0
    x_values = [x0, x1]  # Menyimpan nilai x untuk grafik dan iterasi
    print(f"Iterasi 0: x0 = {x0}, f(x0) = {f(x0)}")
    print(f"Iterasi 1: x1 = {x1}, f(x1) = {f(x1)}")

    while iterasi < max_iter:
        # Hitung nilai f(x) di kedua titik
        f_x0 = f(x0)
        f_x1 = f(x1)

        # Formula metode secant
        x2 = x1 - f_x1 * (x1 - x0) / (f_x1 - f_x0)

        # Menambahkan nilai x2 ke daftar untuk grafik
        x_values.append(x2)

        # Menampilkan iterasi
        print(f"Iterasi {iterasi + 2}: x2 = {x2}, f(x2) = {f(x2)}")

        # Jika perubahan antara x1 dan x2 cukup kecil, berhenti
        if abs(x2 - x1) < tol:
            break

        # Update x0 dan x1 untuk iterasi berikutnya
        x0, x1 = x1, x2
        iterasi += 1

    return x2, iterasi, x_values

# Parameter awal
x0 = 1.0  # Titik awal x0
x1 = 3.0  # Titik awal x1

# Menjalankan metode secant
akar, iterasi, x_values = secant_method(f, x0, x1)

# Menampilkan hasil akar dan jumlah iterasi
print(f"\nAkar yang ditemukan: {akar}")
print(f"Jumlah iterasi: {iterasi}")

# Membuat grafik fungsi dan titik iterasi
x = np.linspace(0, 5, 400)
y = f(x)

# Plot grafik fungsi
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="f(x) = x^3 - 2x^2 + 2x - 5 = 0", color="blue")
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)

# Plot titik-titik iterasi metode secant
for i, xi in enumerate(x_values):
    plt.plot(xi, f(xi), 'ro')  # Titik merah untuk iterasi
    plt.text(xi, f(xi), f' Iter {i}', color='red')

# Menambahkan label dan title
plt.title('Grafik Fungsi dan Iterasi Metode Secant')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Iterasi 0: x0 = 1.0, f(x0) = -4.0
# Iterasi 1: x1 = 3.0, f(x1) = 10.0
# Iterasi 2: x2 = 1.5714285714285714, f(x2) = -2.9154518950437316
# Iterasi 3: x2 = 1.8939051918735892, f(x2) = -1.592738630164491
# Iterasi 4: x2 = 2.282213818047807, f(x2) = 1.0343382823619613
# Iterasi 5: x2 = 2.129328123872559, f(x2) = -0.1549650906371829
# Iterasi 6: x2 = 2.1492489834218347, f(x2) = -0.012080503490151884
# Iterasi 7: x2 = 2.1509332379528305, f(x2) = 0.0001611832871750707
#
# Akar yang ditemukan: 2.1509332379528305
# Jumlah iterasi: 5

# %% [markdown]
#  X0 = 1 dan X1 = 4

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fungsi yang ingin dicari akarnya
def f(x):
    # f(x) = x^3 - 2x^2 + 2x - 5 = 0
    return x**3 - 2*x**2 + 2*x - 5

# Metode Secant
def secant_method(f, x0, x1, tol=0.01, max_iter=100):
    iterasi = 0
    x_values = [x0, x1]  # Menyimpan nilai x untuk grafik dan iterasi
    print(f"Iterasi 0: x0 = {x0}, f(x0) = {f(x0)}")
    print(f"Iterasi 1: x1 = {x1}, f(x1) = {f(x1)}")

    while iterasi < max_iter:
        # Hitung nilai f(x) di kedua titik
        f_x0 = f(x0)
        f_x1 = f(x1)

        # Formula metode secant
        x2 = x1 - f_x1 * (x1 - x0) / (f_x1 - f_x0)

        # Menambahkan nilai x2 ke daftar untuk grafik
        x_values.append(x2)

        # Menampilkan iterasi
        print(f"Iterasi {iterasi + 2}: x2 = {x2}, f(x2) = {f(x2)}")

        # Jika perubahan antara x1 dan x2 cukup kecil, berhenti
        if abs(x2 - x1) < tol:
            break

        # Update x0 dan x1 untuk iterasi berikutnya
        x0, x1 = x1, x2
        iterasi += 1

    return x2, iterasi, x_values

# Parameter awal
x0 = 1.0  # Titik awal x0
x1 = 4.0  # Titik awal x1

# Menjalankan metode secant
akar, iterasi, x_values = secant_method(f, x0, x1)

# Menampilkan hasil akar dan jumlah iterasi
print(f"\nAkar yang ditemukan: {akar}")
print(f"Jumlah iterasi: {iterasi}")

# Membuat grafik fungsi dan titik iterasi
x = np.linspace(0, 5, 400)
y = f(x)

# Plot grafik fungsi
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="f(x) = x^3 - 2x^2 + 2x - 5 = 0", color="blue")
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)

# Plot titik-titik iterasi metode secant
for i, xi in enumerate(x_values):
    plt.plot(xi, f(xi), 'ro')  # Titik merah untuk iterasi
    plt.text(xi, f(xi), f' Iter {i}', color='red')

# Menambahkan label dan title
plt.title('Grafik Fungsi dan Iterasi Metode Secant')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Iterasi 0: x0 = 1.0, f(x0) = -4.0
# Iterasi 1: x1 = 4.0, f(x1) = 35.0
# Iterasi 2: x2 = 1.3076923076923075, f(x2) = -3.5685025034137463
# Iterasi 3: x2 = 1.5567947129285418, f(x2) = -2.9605672416402427
# Iterasi 4: x2 = 2.7698916775703957, f(x2) = 6.446623200189158
# Iterasi 5: x2 = 1.938572370844592, f(x2) = -1.353704148604896
# Iterasi 6: x2 = 2.0828432897444316, f(x2) = -0.47491966453042345
# Iterasi 7: x2 = 2.1608113213233793, f(x2) = 0.07246767817134092
# Iterasi 8: x2 = 2.1504892663919875, f(x2) = -0.0030681911309793364
# Iterasi 9: x2 = 2.150908537894209, f(x2) = -1.8526890973369348e-05
#
# Akar yang ditemukan: 2.150908537894209
# Jumlah iterasi: 7

# %% [markdown]
#   Dengan ketiga percobaan <br>
#   1. X0 = 2 dan X1 = 3 (3 iterasi)
#   2. X0 = 1 dan X1 = 3 (5 iterasi)
#   3. X0 = 1 dan X1 = 4 (7 iterasi)
#
# Kesimpulan: Semakin dekat titik awal dengan akar, semakin cepat konvergensi metode Secant.

# %% [markdown]
# # 2

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# Analisis:
#
# Iterasi 0: x0 = 3.0, f(x0) = 1.0 - masih jauh dari nol.  <br>
# Iterasi 1: x1 = 4.0, f(x1) = 6.0 - masih jauh dari nol.  <br>
# Iterasi 2: x2 = 2.8, f(x2) = 0.23999999999999932 - mulai mendekati akar <br>
# Iterasi 3: x2 = 2.75, f(x2) = 0.0625 - mulai mendekati akar <br>
# Iterasi 4: x2 = 2.732394366197183, f(x2) = 0.00119024003173962 - semakin kecil, mendekati nol <br>
# Iterasi 5: x2 = 2.732052578361982, f(x2) = 6.134210389419081e-06 - semakin kecil, mendekati nol <br>
# Iterasi 6: x2 = 2.732050807744481, f(x2) = 6.08309846938937e-10 - Akar ditemukan <br>
# Iterasi 7: x2 = 2.732050807568877, f(x2) = 0.0 - Akar ditemukan <br>
#
# **Kesimpulan: Metode Secant menemukan akar x = 2.732 x=2.732 dalam 5 iterasi dengan akurasi tinggi.**
